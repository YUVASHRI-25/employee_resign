# %%
import pandas as pd 
df=pd.read_csv("E:/PYTHON/ML_PROJECT/Extended_Employee_Performance_and_Productivity_Data (1).csv")
df
# Out:
#        Employee_ID        Department  Gender  Age   Job_Title  \
# 0                1                IT    Male   55  Specialist
# 1                2           Finance    Male   29   Developer
# 2                3           Finance    Male   55  Specialist
# 3                4  Customer Support  Female   48     Analyst
# 4                5       Engineering  Female   36     Analyst
# ...            ...               ...     ...  ...         ...
# 99995        99996           Finance    Male   27  Technician
# 99996        99997                IT  Female   36  Consultant
# 99997        99998        Operations    Male   53     Analyst
# 99998        99999                HR  Female   22  Consultant
# 99999       100000           Finance  Female   43     Analyst
#
#                         Hire_Date  Years_At_Company Education_Level  \
# 0      2022-01-19 08:03:05.556036                 2     High School
# 1      2024-04-18 08:03:05.556036                 0     High School
# ...

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Department', 'Gender', 'Age', 'Job_Title', 'Hire_Date',
#        'Years_At_Company', 'Education_Level', 'Performance_Score',
#        'Monthly_Salary', 'Work_Hours_Per_Week', 'Projects_Handled',
#        'Overtime_Hours', 'Sick_Days', 'Remote_Work_Frequency', 'Team_Size',
#        'Training_Hours', 'Promotions', 'Employee_Satisfaction_Score',
#        'Resigned'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Employee_ID            Age  Years_At_Company  Performance_Score  \
# count  100000.000000  100000.000000     100000.000000      100000.000000
# mean    50000.500000      41.029410          4.476070           2.995430
# std     28867.657797      11.244121          2.869336           1.414726
# min         1.000000      22.000000          0.000000           1.000000
# 25%     25000.750000      31.000000          2.000000           2.000000
# 50%     50000.500000      41.000000          4.000000           3.000000
# 75%     75000.250000      51.000000          7.000000           4.000000
# max    100000.000000      60.000000         10.000000           5.000000
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# count   100000.000000        100000.000000     100000.000000   100000.000000
# mean      6403.211000            44.956950         24.431170       14.514930
# std       1372.508717             8.942003         14.469584        8.664026
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID                    0
# Department                     0
# Gender                         0
# Age                            0
# Job_Title                      0
# Hire_Date                      0
# Years_At_Company               0
# Education_Level                0
# Performance_Score              0
# Monthly_Salary                 0
# Work_Hours_Per_Week            0
# Projects_Handled               0
# Overtime_Hours                 0
# Sick_Days                      0
# Remote_Work_Frequency          0
# Team_Size                      0
# Training_Hours                 0
# Promotions                     0
# Employee_Satisfaction_Score    0
# Resigned                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(x='Resigned', data=df, palette='Set2')

plt.title('Distribution of Employee Resignations')
plt.xlabel('Resigned (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.xticks([0, 1], ['No', 'Yes'], rotation=0)  

plt.show()
# Out:
# C:\Users\MOHAN\AppData\Local\Temp\ipykernel_4132\24885086.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Resigned', data=df, palette='Set2')

# %%
df_random = df.sample(n=5000, random_state=42)
print(df_random.shape)
df_random.to_csv("new_random_5000_rows.csv",index=False)
# Out:
# (5000, 20)

# %%
df.isnull().sum()
# Out:
# Employee_ID                    0
# Department                     0
# Gender                         0
# Age                            0
# Job_Title                      0
# Hire_Date                      0
# Years_At_Company               0
# Education_Level                0
# Performance_Score              0
# Monthly_Salary                 0
# Work_Hours_Per_Week            0
# Projects_Handled               0
# Overtime_Hours                 0
# Sick_Days                      0
# Remote_Work_Frequency          0
# Team_Size                      0
# Training_Hours                 0
# Promotions                     0
# Employee_Satisfaction_Score    0
# Resigned                       0
# dtype: int64

# %%
numeric_df = df_random.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(20,10))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %%
df.columns.tolist()
# Out:
# ['Employee_ID',
#  'Department',
#  'Gender',
#  'Age',
#  'Job_Title',
#  'Hire_Date',
#  'Years_At_Company',
#  'Education_Level',
#  'Performance_Score',
#  'Monthly_Salary',
#  'Work_Hours_Per_Week',
#  'Projects_Handled',
#  'Overtime_Hours',
#  'Sick_Days',
#  'Remote_Work_Frequency',
#  'Team_Size',
#  'Training_Hours',
#  'Promotions',
#  'Employee_Satisfaction_Score',
#  'Resigned']

# %%
import pandas as pd
print(df_random.skew(numeric_only=True))
# Out:
# Employee_ID                    0.014025
# Age                           -0.027405
# Years_At_Company               0.000157
# Performance_Score              0.030854
# Monthly_Salary                 0.119192
# Work_Hours_Per_Week            0.017149
# Projects_Handled               0.049082
# Overtime_Hours                -0.012452
# Sick_Days                     -0.014019
# Remote_Work_Frequency          0.023060
# Team_Size                      0.015270
# Training_Hours                -0.010260
# Promotions                    -0.004783
# Employee_Satisfaction_Score    0.041323
# Resigned                       2.612979
# dtype: float64

# %%
categorical_cols = ['Department', 'Gender', 'Job_Title', 'Education_Level']

for col in categorical_cols:
    print(f"\nUnique values in {col}:")
    print(df[col].unique())
    print("Count:", df[col].nunique())
# Out:
# Unique values in Department:
# ['Sales' 'Marketing' 'Operations' 'Customer Support' 'Legal' 'Finance'
#  'IT' 'HR' 'Engineering']
# Count: 9
#
# Unique values in Gender:
# ['Other' 'Male' 'Female']
# Count: 3
#
# Unique values in Job_Title:
# ['Manager' 'Engineer' 'Analyst' 'Technician' 'Specialist' 'Developer'
#  'Consultant']
# Count: 7
#
# Unique values in Education_Level:
# ['Master' 'High School' 'Bachelor' 'PhD']
# Count: 4

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# 1. Load dataset
df = pd.read_csv("E:/PYTHON/ML_PROJECT/new_random_5000_rows.csv")

# 2. Encode categorical variables (manual mapping)
df['Department'] = df['Department'].map({
    'Sales': 0,
    'Marketing': 1,
    'Operations': 2,
    'Customer Support': 3,
    'Legal': 4,
    'Finance': 5,
    'IT': 6,
    'HR': 7,
    'Engineering': 8
})

df['Gender'] = df['Gender'].map({
    'Other': 0,
    'Male': 1,
    'Female': 2
})

df['Job_Title'] = df['Job_Title'].map({
    'Manager': 0,
    'Engineer': 1,
    'Analyst': 2,
    'Technician': 3,
    'Specialist': 4,
    'Developer': 5,
    'Consultant': 6
})

df['Education_Level'] = df['Education_Level'].map({
    'High School': 0,
    'Bachelor': 1,
    'Master': 2,
    'PhD': 3
})

# 3. Define X and y AFTER mapping
X = df.drop(columns=['Employee_ID', 'Hire_Date', 'Resigned'])
y = df['Resigned'].map({True: 1, False: 0})

# 4. Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# 5. Apply SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_train, y_train)

print("Before SMOTE:\n", y_train.value_counts())
print("\nAfter SMOTE:\n", y_res.value_counts())
# Out:
# Before SMOTE:
#  Resigned
# 0    3588
# 1     412
# Name: count, dtype: int64
#
# After SMOTE:
#  Resigned
# 0    3588
# 1    3588
# Name: count, dtype: int64

# %%
import pandas as pd

# Combine resampled features and target
smote_df = pd.concat([X_res, y_res], axis=1)

# Save to CSV
smote_df.to_csv("E:/PYTHON/ML_PROJECT/smote_resampled.csv", index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from imblearn.over_sampling import SMOTE
x_train, x_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)
models = {
    "Logistic Regression": LogisticRegression(max_iter=2000),  # increased iterations
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
}

# %%
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)

    print(f"\nModel: {name}")
    print(f"  Accuracy : {acc:.5f}")
    print(f"  F1 Score : {f1:.4f}")
    print(f"  Precision: {prec:.4f}")
    print(f"  Recall   : {rec:.4f}")
# Out:
# c:\Users\MOHAN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model: Logistic Regression
#   Accuracy : 0.64415
#   F1 Score : 0.6363
#   Precision: 0.6478
#   Recall   : 0.6252
#
# Model: Decision Tree
#   Accuracy : 0.81546
#   F1 Score : 0.8194
#   Precision: 0.7992
#   Recall   : 0.8406
#
# Model: Random Forest
#   Accuracy : 0.89694
#   F1 Score : 0.8944
#   Precision: 0.9127
#   Recall   : 0.8769
#
# Model: Gradient Boosting
#   Accuracy : 0.83426
#   F1 Score : 0.8258
#   Precision: 0.8664
#   Recall   : 0.7888
#
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
y_prob = models["Random Forest"].predict_proba(x_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f"Random Forest (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Random Forest")
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = models["Random Forest"].predict(x_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No", "Yes"])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
rf_params = {
    "n_estimators": [100, 200],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2]
}

rf = RandomForestClassifier(random_state=42)
rf_grid = GridSearchCV(rf, rf_params, cv=cv, scoring="f1", n_jobs=-1, verbose=1)
rf_grid.fit(X_res, y_res)

print("\nBest Random Forest Params:", rf_grid.best_params_)
y_pred_rf = rf_grid.predict(x_test)

print("\nRandom Forest Results:")
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall   :", recall_score(y_test, y_pred_rf))
print("F1 Score :", f1_score(y_test, y_pred_rf))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#
# Best Random Forest Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
# Random Forest Results:
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1 Score : 1.0

# %%
results = []
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)
    results.append([name, acc, f1, prec, rec])

metrics_df = pd.DataFrame(results, columns=["Model", "Accuracy", "F1 Score", "Precision", "Recall"])
display(metrics_df)
# Out:
# c:\Users\MOHAN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                  Model  Accuracy  F1 Score  Precision    Recall
# 0  Logistic Regression  0.644150  0.636299   0.647826  0.625175
# 1        Decision Tree  0.805014  0.810298   0.785808  0.836364
# 2        Random Forest  0.897632  0.894321   0.920118  0.869930
# 3    Gradient Boosting  0.834262  0.825769   0.866359  0.788811
# 4             AdaBoost  0.720056  0.741645   0.686088  0.806993

# %%
import pickle

# suppose your trained model is stored in variable `model`
with open("E:/PYTHON/ML_PROJECT/model.pkl", "wb") as f:
    pickle.dump(model, f)
